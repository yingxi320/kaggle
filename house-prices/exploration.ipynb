# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_train = pd.read_csv("train.csv")

# %%
df_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
# plot the hotmap of the train data
corr = df_train.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corr, vmax=.8, square=True)

# %%
df_train.skew()
# Out:
# Id                0.000000
# MSSubClass        1.407657
# LotFrontage       2.163569
# LotArea          12.207688
# OverallQual       0.216944
# OverallCond       0.693067
# YearBuilt        -0.613461
# YearRemodAdd     -0.503562
# MasVnrArea        2.669084
# BsmtFinSF1        1.685503
# BsmtFinSF2        4.255261
# BsmtUnfSF         0.920268
# TotalBsmtSF       1.524255
# 1stFlrSF          1.376757
# 2ndFlrSF          0.813030
# LowQualFinSF      9.011341
# GrLivArea         1.366560
# BsmtFullBath      0.596067
# BsmtHalfBath      4.103403
# FullBath          0.036562
# HalfBath          0.675897
# BedroomAbvGr      0.211790
# KitchenAbvGr      4.488397
# TotRmsAbvGrd      0.676341
# Fireplaces        0.649565
# GarageYrBlt      -0.649415
# GarageCars       -0.342549
# GarageArea        0.179981
# WoodDeckSF        1.541376
# OpenPorchSF       2.364342
# EnclosedPorch     3.089872
# 3SsnPorch        10.304342
# ScreenPorch       4.122214
# PoolArea         14.828374
# ...

# %%
df_train_dummy = df_train.copy()

# %%
df_train_dummy = pd.get_dummies(df_train_dummy)

# %%
keep_cols = df_train_dummy.select_dtypes(include=["number"]).columns

# %%
df_train_dummy = df_train_dummy[keep_cols]

# %%
keep_cols
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        ...
#        'SaleType_ConLw', 'SaleType_New', 'SaleType_Oth', 'SaleType_WD',
#        'SaleCondition_Abnorml', 'SaleCondition_AdjLand',
#        'SaleCondition_Alloca', 'SaleCondition_Family', 'SaleCondition_Normal',
#        'SaleCondition_Partial'],
#       dtype='object', length=290)

# %%
df_train_dummy = df_train_dummy.fillna(df_train_dummy.mean())

# %%
df_test = pd.read_csv("test.csv")

# %%
df_test_dummy = pd.get_dummies(df_test)

# %%
df_test_dummy = df_test_dummy.fillna(df_test_dummy.mean())

# %%
for col in keep_cols:
    if col not in df_test_dummy:
        df_test_dummy[col] = 0

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
rf = RandomForestRegressor(max_depth=30, n_estimators=500, max_features=100, oob_score=True, random_state=1234)

# %%
cv_score = cross_val_score(rf, df_train_dummy.drop("SalePrice", axis=1), df_train_dummy["SalePrice"], cv=5, n_jobs=-1)

# %%
print("CV Score is: ", str(np.mean(cv_score)))
# Out:
# CV Score is:  0.868731023398

# %%
rf.fit(df_train_dummy.drop("SalePrice", axis=1), df_train_dummy["SalePrice"])
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=30,
#            max_features=100, max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#            oob_score=True, random_state=1234, verbose=0, warm_start=False)

# %%
predict = rf.predict(df_test_dummy.drop("SalePrice", axis=1))

# %%
predict
# Out:
# array([ 123716.338,  150613.728,  179217.736, ...,  164784.67 ,
#         113934.136,  243426.112])

# %%
df_test_dummy.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        ...
#        'RoofMatl_Roll', 'Exterior1st_ImStucc', 'Exterior1st_Stone',
#        'Exterior2nd_Other', 'Heating_Floor', 'Heating_OthW', 'Electrical_Mix',
#        'GarageQual_Ex', 'PoolQC_Fa', 'MiscFeature_TenC'],
#       dtype='object', length=290)

# %%
df_test_dummy.shape
# Out:
# (1459, 290)

# %%
df_result1 = pd.DataFrame(df_test_dummy["Id"].values, columns=["Id"])

# %%
df_test_dummy["Id"].values
# Out:
# array([1461, 1462, 1463, ..., 2917, 2918, 2919], dtype=int64)

# %%
df_result1["SalePrice"] = predict

# %%
df_result1
# Out:
#         Id   SalePrice
# 0     1461  123716.338
# 1     1462  150613.728
# 2     1463  179217.736
# 3     1464  177991.564
# 4     1465  200955.672
# 5     1466  180736.480
# 6     1467  166223.166
# 7     1468  167484.064
# 8     1469  175468.072
# 9     1470  117544.032
# 10    1471  187724.298
# 11    1472   98684.302
# 12    1473  101196.952
# 13    1474  158838.974
# 14    1475  131631.524
# 15    1476  329623.892
# 16    1477  254994.756
# 17    1478  274059.074
# 18    1479  257629.646
# 19    1480  405909.094
# 20    1481  302799.050
# 21    1482  202392.162
# 22    1483  171356.798
# 23    1484  164123.848
# 24    1485  161825.686
# 25    1486  188207.726
# 26    1487  314533.388
# 27    1488  241669.126
# 28    1489  189859.062
# 29    1490  193095.986
# ...    ...         ...
# 1429  2890   82311.346
# 1430  2891  142095.966
# 1431  2892   71003.970
# 1432  2893  113208.284
# 1433  2894   71904.768
# 1434  2895  265589.096
# 1435  2896  253356.740
# 1436  2897  203178.784
# ...

# %%
df_result1.to_csv("base_model.csv", index=False)

# %%
df_test_t
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# 5     1466          60       RL         75.0    10000   Pave   NaN      IR1
# 6     1467          20       RL          NaN     7980   Pave   NaN      IR1
# 7     1468          60       RL         63.0     8402   Pave   NaN      IR1
# 8     1469          20       RL         85.0    10176   Pave   NaN      Reg
# 9     1470          20       RL         70.0     8400   Pave   NaN      Reg
# 10    1471         120       RH         26.0     5858   Pave   NaN      IR1
# ...

# %%
df_test_t["Id"].values
# Out:
# array([1461, 1462, 1463, ..., 2917, 2918, 2919], dtype=int64)

# %%
df_test_dummy["Id"]
# Out:
# 0       1461
# 1       1462
# 2       1463
# 3       1464
# 4       1465
# 5       1466
# 6       1467
# 7       1468
# 8       1469
# 9       1470
# 10      1471
# 11      1472
# 12      1473
# 13      1474
# 14      1475
# 15      1476
# 16      1477
# 17      1478
# 18      1479
# 19      1480
# 20      1481
# 21      1482
# 22      1483
# 23      1484
# 24      1485
# 25      1486
# 26      1487
# 27      1488
# 28      1489
# 29      1490
#         ...
# 1429    2890
# 1430    2891
# 1431    2892
# 1432    2893
# 1433    2894
# 1434    2895
# 1435    2896
# 1436    2897
# 1437    2898
# 1438    2899
# 1439    2900
# 1440    2901
# 1441    2902
# 1442    2903
# 1443    2904
# 1444    2905
# 1445    2906
# 1446    2907
# 1447    2908
# 1448    2909
# 1449    2910
# 1450    2911
# 1451    2912
# 1452    2913
# 1453    2914
# 1454    2915
# 1455    2916
# 1456    2917
# 1457    2918
# 1458    2919
# Name: Id, Length: 1459, dtype: int64

# %%
sns.barplot(data=df_train, x="Neighborhood", y="LotFrontage", estimator=np.median)
plt.xticks(rotation=90)
plt.show()

# %%
gb_neigh_LF = df_train["LotFrontage"].groupby(df_train["Neighborhood"])

# %%
df_train_LFm = df_train.copy()

# %%
for key, group in gb_neigh_LF:
    lot_f_null_nei = df_train["LotFrontage"].isnull() & (df_train["Neighborhood"] == key)
    df_train_LFm.loc[lot_f_null_nei, "LotFrontage"] = group.mean()

# %%
df_train_median = df_train.copy()

# %%
for key, group in gb_neigh_LF:
    lot_f_null_nei = df_train_median["LotFrontage"].isnull() & (df_train_median["Neighborhood"] == key)
    df_train_median.loc[lot_f_null_nei, "LotFrontage"] = group.median()

# %%
df_train_median = pd.get_dummies(df_train_median)

# %%
keep_cols = df_train_median.select_dtypes(include=["number"]).columns

# %%
df_train_median = df_train_median[keep_cols]

# %%
df_train_median = df_train_median.fillna(df_train_median.median())

# %%
rf = RandomForestRegressor(max_depth=30, n_estimators=500, max_features=100, oob_score=True, n_jobs=-1, random_state=1234)

# %%
cv_sorce = cross_val_score(rf, df_train_median.drop("SalePrice", axis=1), df_train_median["SalePrice"], cv=5, n_jobs=-1, verbose=2)
# Out:
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   25.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   25.9s finished

# %%
print("CV Sorce is: ", np.mean(cv_score))
# Out:
# CV Sorce is:  0.868731023398

# %%
rf.fit(df_train_median.drop("SalePrice", axis=1), df_train_median["SalePrice"])
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=30,
#            max_features=100, max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=-1,
#            oob_score=True, random_state=1234, verbose=0, warm_start=False)

# %%
predict = rf.predict(df_test_dummy.drop("SalePrice", axis=1))

# %%
result = pd.DataFrame(df_test["Id"].values, columns=["Id"])

# %%
result["SalePrice"] = predict
result.to_csv("base_model_median.csv", index=False)

# %%
sns.barplot(data=df_train, x="MSSubClass", y="SalePrice")
plt.show()

# %%
#use xgboost
from xgboost.sklearn import XGBRegressor
# Out:
# c:\python3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
xgb = XGBRegressor(learning_rate=0.05, max_depth=3, n_estimators=500, colsample_bytree=0.4)

# %%
cv_score = cross_val_score(xgb, df_train_median.drop("SalePrice", axis=1), df_train_median["SalePrice"], cv=5, n_jobs=-1, verbose=2)
# Out:
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    9.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    9.2s finished

# %%
print("CV Score is: ", np.mean(cv_score))
# Out:
# CV Score is:  0.897402636334

# %%
df_train_median.sort_index(axis=1, inplace=True)
xgb.fit(df_train_median.drop("SalePrice", axis=1), df_train_median["SalePrice"], verbose=2)
# Out:
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.4,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=-1,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=1)

# %%
df_test_dummy.sort_index(axis=1, inplace=True)
predict = xgb.predict(df_test_dummy.drop("SalePrice", axis=1))

# %%
result = pd.DataFrame(df_test["Id"].values, columns=["Id"])
result["SalePrice"] = predict
result.to_csv("xgb1.csv", index=False)

# %%
has_rank = [col for col in df_train if "TA" in list(df_train[col])]

# %%
dic_num = {"None": 0, "Po": 1, "Fa": 2, "Ta": 3, "Gd": 4, "Ex": 5}

# %%
df_train_c2n = df_train.copy()

# %%
df_train_c2n["MSSubClass"] = df_train_c2n["MSSubClass"].astype("category")

# %%
for key, group in gb_neigh_LF:
    lot_f_null_nei = df_train["LotFrontage"].isnull() & (df_train["Neighborhood"] == key)
    df_train_c2n.loc[lot_f_null_nei, "LotFrontage"] = group.median()

# %%
for col in has_rank:
    df_train_c2n[col + "_2num"] = df_train_c2n[col].map(dic_num)

# %%
from statistics import mode

# %%
low_var_cat = [col for col in df_train.select_dtypes(exclude=["number"]) if 1 - sum(df_train[col] == mode(df_train[col])) / len(df_train[col]) < 0.03]

# %%
low_var_cat
# Out:
# ['Street', 'Utilities', 'Condition2', 'RoofMatl', 'Heating']

# %%
df_train_col = df_train.copy()

# %%
df_train_col = df_train_col.drop(low_var_cat, axis=1)

# %%
df_train_col["MSSubClass"] = df_train_col["MSSubClass"].astype("category")

# %%
for key, group in gb_neigh_LF:
    lot_f_null_nei = df_train["LotFrontage"].isnull() & (df_train["Neighborhood"] == key)
    df_train_col.loc[lot_f_null_nei, "LotFrontage"] = group.median()

# %%
for col in has_rank:
    df_train_col[col + "_2num"] = df_train_col[col].map(dic_num)

# %%
df_train_col = pd.get_dummies(df_train_col)

# %%
cols = df_train_col.select_dtypes(include=["number"]).columns

# %%
df_train_col = df_train_col[cols]

# %%
df_train_col = df_train_col.fillna(df_train_col.median())

# %%
xgb = XGBRegressor(learning_rate=0.05,n_estimators=500,max_depth=3,colsample_bytree=0.4)
cv_score = cross_val_score(xgb, df_train_col.drop(['SalePrice','Id'], axis = 1), df_train_col['SalePrice'], cv = 5, n_jobs=-1)

# %%
print("CV Score is: ", np.mean(cv_score))
# Out:
# CV Score is:  0.895899501295

# %%
#test
df_test_col = df_test.copy()

# %%
df_test_col = df_test_col.drop(low_var_cat, axis=1)

# %%
df_test_col["MSSubClass"] = df_test_col["MSSubClass"].astype("category")

# %%
for key, group in gb_neigh_LF:
    lot_f_null_nei = df_test["LotFrontage"].isnull() & (df_test["Neighborhood"] == key)
    df_test_col.loc[lot_f_null_nei, "LotFrontage"] = group.median()

# %%
for col in has_rank:
    df_test_col[col + "_2num"] = df_test_col[col].map(dic_num)

# %%
df_test_col = pd.get_dummies(df_test_col)

# %%
cols = df_test_col.select_dtypes(include=["number"]).columns

# %%
df_test_col = df_test_col[cols]

# %%
df_test_col = df_test_col.fillna(df_test_col.median())

# %%
df_train_col.sort_index(axis=1, inplace=True)
xgb.fit(df_train_col.drop(["SalePrice", "Id"], axis=1), df_train_col["SalePrice"])
# Out:
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.4,
#        gamma=0, learning_rate=0.05, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=500, nthread=-1,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=1)

# %%
df_test_col.sort_index(axis=1, inplace=True)
predict = xgb.predict(df_test_col.drop(["SalePrice", "Id"], axis=1))

# %%
cols = df_train_col.select_dtypes(include=["number"]).columns

# %%
for col in cols:
    if col not in df_test_col:
        df_test_col[col] = 0

# %%
df_test_col.drop("SalePrice", axis=1).columns
# Out:
# Index(['1stFlrSF', '2ndFlrSF', '3SsnPorch', 'Alley_Grvl', 'Alley_Pave',
#        'BedroomAbvGr', 'BldgType_1Fam', 'BldgType_2fmCon', 'BldgType_Duplex',
#        'BldgType_Twnhs',
#        ...
#        'SaleType_New', 'SaleType_Oth', 'SaleType_WD', 'ScreenPorch',
#        'TotRmsAbvGrd', 'TotalBsmtSF', 'WoodDeckSF', 'YearBuilt',
#        'YearRemodAdd', 'YrSold'],
#       dtype='object', length=286)

# %%
df_test_col = df_test_col[cols]

# %%
df_train_col.columns
# Out:
# Index(['1stFlrSF', '2ndFlrSF', '3SsnPorch', 'Alley_Grvl', 'Alley_Pave',
#        'BedroomAbvGr', 'BldgType_1Fam', 'BldgType_2fmCon', 'BldgType_Duplex',
#        'BldgType_Twnhs',
#        ...
#        'SaleType_New', 'SaleType_Oth', 'SaleType_WD', 'ScreenPorch',
#        'TotRmsAbvGrd', 'TotalBsmtSF', 'WoodDeckSF', 'YearBuilt',
#        'YearRemodAdd', 'YrSold'],
#       dtype='object', length=287)

# %%
df_test_col.columns
# Out:
# Index(['1stFlrSF', '2ndFlrSF', '3SsnPorch', 'Alley_Grvl', 'Alley_Pave',
#        'BedroomAbvGr', 'BldgType_1Fam', 'BldgType_2fmCon', 'BldgType_Duplex',
#        'BldgType_Twnhs',
#        ...
#        'SaleType_New', 'SaleType_Oth', 'SaleType_WD', 'ScreenPorch',
#        'TotRmsAbvGrd', 'TotalBsmtSF', 'WoodDeckSF', 'YearBuilt',
#        'YearRemodAdd', 'YrSold'],
#       dtype='object', length=287)

# %%
t = df_train_col.columns == df_test_col.columns

# %%
len(t)
# Out:
# 287

# %%
result = pd.DataFrame(df_test_col["Id"].values, columns=["Id"])
result["SalePrice"] = predict
result.to_csv("xgb2.csv", index=False)
